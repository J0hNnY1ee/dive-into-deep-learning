# %%
import numpy as np
import torch
from torch.utils import data
from d2l import torch as d2l

true_w = torch.tensor([2, -3.4])
true_b = 4.2
features, labels = d2l.synthetic_data(true_w, true_b, 1000)


def load_array(data_arrays, batch_size, is_train=True):  #@save
    """构造一个PyTorch数据迭代器"""
    dataset = data.TensorDataset(*data_arrays)
    return data.DataLoader(dataset, batch_size, shuffle=is_train)

batch_size = 10
data_iter = load_array((features, labels), batch_size)
next(iter(data_iter))
# Out:
# [tensor([[-0.1065,  1.0438],
#          [ 0.6571,  0.0146],
#          [-1.6059, -0.0131],
#          [-0.2410,  0.2102],
#          [ 0.5447,  0.8281],
#          [-1.1177,  1.4481],
#          [-0.0449, -0.4264],
#          [-0.0696,  0.2413],
#          [ 0.4518,  0.7356],
#          [ 0.1022, -0.6304]]),
#  tensor([[ 0.4500],
#          [ 5.4573],
#          [ 1.0359],
#          [ 2.9977],
#          [ 2.4744],
#          [-2.9756],
#          [ 5.5686],
#          [ 3.2466],
#          [ 2.6061],
#          [ 6.5235]])]

# %%
from torch import nn
net = nn.Sequential(nn.Linear(2, 1))
net[0].weight.data.normal_(0, 0.01)
net[0].bias.data.fill_(0)
# loss = nn.MSELoss()
loss = nn.HuberLoss() #practice 2

trainer = torch.optim.SGD(net.parameters(), lr=0.03)

# %%
num_epochs = 3
for epoch in range(num_epochs):
    for X, y in data_iter:
        l = loss(net(X), y)
        trainer.zero_grad()
        l.backward()
        trainer.step()
    l = loss(net(features), labels)
    print(f"epoch {epoch + 1}, loss {l:f}")


w = net[0].weight.data
print("w的估计误差：", true_w - w.reshape(true_w.shape))
b = net[0].bias.data
print("b的估计误差：", true_b - b)
# Out:
# Epoch 1, Weight Gradient: tensor([[-0.3168,  0.4389]]), Bias Gradient: tensor([-0.3123])
# Epoch 1, Weight Gradient: tensor([[0.0172, 0.3234]]), Bias Gradient: tensor([-0.9406])
# Epoch 1, Weight Gradient: tensor([[-0.2294,  0.7934]]), Bias Gradient: tensor([-0.6470])
# Epoch 1, Weight Gradient: tensor([[-0.2295, -0.1678]]), Bias Gradient: tensor([-0.9648])
# Epoch 1, Weight Gradient: tensor([[-0.3700,  0.1211]]), Bias Gradient: tensor([-1.0000])
# Epoch 1, Weight Gradient: tensor([[-0.5573,  0.2679]]), Bias Gradient: tensor([-0.8000])
# Epoch 1, Weight Gradient: tensor([[-0.4059,  0.0580]]), Bias Gradient: tensor([-0.7490])
# Epoch 1, Weight Gradient: tensor([[-0.4140,  0.5913]]), Bias Gradient: tensor([-0.6000])
# Epoch 1, Weight Gradient: tensor([[-0.4732,  0.4488]]), Bias Gradient: tensor([-0.6000])
# Epoch 1, Weight Gradient: tensor([[-0.2171,  0.3377]]), Bias Gradient: tensor([-0.7766])
# Epoch 1, Weight Gradient: tensor([[-0.7208,  0.1912]]), Bias Gradient: tensor([-0.5261])
# Epoch 1, Weight Gradient: tensor([[0.1735, 0.3111]]), Bias Gradient: tensor([-0.8368])
# Epoch 1, Weight Gradient: tensor([[-0.2951, -0.0510]]), Bias Gradient: tensor([-0.6185])
# Epoch 1, Weight Gradient: tensor([[0.0070, 0.4488]]), Bias Gradient: tensor([-0.8000])
# Epoch 1, Weight Gradient: tensor([[-0.7130,  0.4675]]), Bias Gradient: tensor([-0.8000])
# Epoch 1, Weight Gradient: tensor([[-0.5191,  0.3102]]), Bias Gradient: tensor([-0.9428])
# Epoch 1, Weight Gradient: tensor([[-0.3107,  0.3237]]), Bias Gradient: tensor([-0.8844])
# Epoch 1, Weight Gradient: tensor([[-0.9322,  0.4315]]), Bias Gradient: tensor([-0.4000])
# Epoch 1, Weight Gradient: tensor([[0.2535, 0.5525]]), Bias Gradient: tensor([-0.6459])
# Epoch 1, Weight Gradient: tensor([[-0.6600,  0.0781]]), Bias Gradient: tensor([-1.0000])
# Epoch 1, Weight Gradient: tensor([[-0.1534,  0.6228]]), Bias Gradient: tensor([-0.6000])
# Epoch 1, Weight Gradient: tensor([[-0.1370,  0.4549]]), Bias Gradient: tensor([-0.8000])
# Epoch 1, Weight Gradient: tensor([[-0.1583,  0.6972]]), Bias Gradient: tensor([-0.5505])
# Epoch 1, Weight Gradient: tensor([[-0.8997,  0.5214]]), Bias Gradient: tensor([-0.5194])
# Epoch 1, Weight Gradient: tensor([[-0.1980,  0.2343]]), Bias Gradient: tensor([-0.9677])
# Epoch 1, Weight Gradient: tensor([[-0.2520,  0.0825]]), Bias Gradient: tensor([-0.9492])
# Epoch 1, Weight Gradient: tensor([[-0.2692,  0.3060]]), Bias Gradient: tensor([-0.5053])
# Epoch 1, Weight Gradient: tensor([[-0.0641, -0.1802]]), Bias Gradient: tensor([-0.7535])
# Epoch 1, Weight Gradient: tensor([[0.1091, 0.3102]]), Bias Gradient: tensor([-0.8000])
# Epoch 1, Weight Gradient: tensor([[-0.1269,  0.8305]]), Bias Gradient: tensor([-0.7215])
# Epoch 1, Weight Gradient: tensor([[-0.4100, -0.1273]]), Bias Gradient: tensor([-0.8298])
# Epoch 1, Weight Gradient: tensor([[-0.1549,  0.3199]]), Bias Gradient: tensor([-0.7966])
# Epoch 1, Weight Gradient: tensor([[0.1613, 0.6049]]), Bias Gradient: tensor([-0.3855])
# Epoch 1, Weight Gradient: tensor([[-0.1467,  0.3916]]), Bias Gradient: tensor([-0.8000])
# Epoch 1, Weight Gradient: tensor([[0.2034, 0.5437]]), Bias Gradient: tensor([-0.4804])
# Epoch 1, Weight Gradient: tensor([[-0.4808,  0.2553]]), Bias Gradient: tensor([-0.5278])
# Epoch 1, Weight Gradient: tensor([[-0.3451,  0.5161]]), Bias Gradient: tensor([-0.2308])
# Epoch 1, Weight Gradient: tensor([[-0.4690,  0.2271]]), Bias Gradient: tensor([-1.0000])
# Epoch 1, Weight Gradient: tensor([[-0.5088,  0.3204]]), Bias Gradient: tensor([-0.7626])
# Epoch 1, Weight Gradient: tensor([[-0.4100, -0.2699]]), Bias Gradient: tensor([-0.9935])
# Epoch 1, Weight Gradient: tensor([[-0.0612,  0.4100]]), Bias Gradient: tensor([-0.4000])
# Epoch 1, Weight Gradient: tensor([[-0.2893,  0.2638]]), Bias Gradient: tensor([-0.5062])
# Epoch 1, Weight Gradient: tensor([[-0.4786,  0.4716]]), Bias Gradient: tensor([-0.3907])
# Epoch 1, Weight Gradient: tensor([[-0.5269,  0.4849]]), Bias Gradient: tensor([-0.2828])
# Epoch 1, Weight Gradient: tensor([[-0.4626,  0.4979]]), Bias Gradient: tensor([-0.3641])
# Epoch 1, Weight Gradient: tensor([[-0.4996,  0.4679]]), Bias Gradient: tensor([-0.2272])
# Epoch 1, Weight Gradient: tensor([[-0.2587, -0.0534]]), Bias Gradient: tensor([-0.9858])
# Epoch 1, Weight Gradient: tensor([[0.1192, 0.8212]]), Bias Gradient: tensor([-1.0000])
# Epoch 1, Weight Gradient: tensor([[-0.3887,  0.3513]]), Bias Gradient: tensor([-0.3074])
# Epoch 1, Weight Gradient: tensor([[-0.2130,  0.5889]]), Bias Gradient: tensor([-0.8000])
# Epoch 1, Weight Gradient: tensor([[0.0393, 0.5516]]), Bias Gradient: tensor([-0.6005])
# Epoch 1, Weight Gradient: tensor([[-0.8072,  0.0986]]), Bias Gradient: tensor([-0.6975])
# Epoch 1, Weight Gradient: tensor([[0.1040, 0.5497]]), Bias Gradient: tensor([-0.5191])
# Epoch 1, Weight Gradient: tensor([[-0.0105,  0.2911]]), Bias Gradient: tensor([-0.8694])
# Epoch 1, Weight Gradient: tensor([[-0.1899,  0.9142]]), Bias Gradient: tensor([-0.3587])
# Epoch 1, Weight Gradient: tensor([[-0.2491,  0.3180]]), Bias Gradient: tensor([-0.8816])
# Epoch 1, Weight Gradient: tensor([[-0.1158, -0.0919]]), Bias Gradient: tensor([-0.9695])
# Epoch 1, Weight Gradient: tensor([[-0.1489,  0.7916]]), Bias Gradient: tensor([-0.8371])
# Epoch 1, Weight Gradient: tensor([[-0.0759,  0.4396]]), Bias Gradient: tensor([-0.6900])
# Epoch 1, Weight Gradient: tensor([[-0.5663,  0.2227]]), Bias Gradient: tensor([-0.3303])
# Epoch 1, Weight Gradient: tensor([[-0.5605,  0.8103]]), Bias Gradient: tensor([-0.5191])
# Epoch 1, Weight Gradient: tensor([[-0.4896,  0.3790]]), Bias Gradient: tensor([-0.6311])
# Epoch 1, Weight Gradient: tensor([[-0.3865,  0.3664]]), Bias Gradient: tensor([-0.6705])
# Epoch 1, Weight Gradient: tensor([[-0.4401, -0.0059]]), Bias Gradient: tensor([-0.8862])
# Epoch 1, Weight Gradient: tensor([[-0.3334,  0.9865]]), Bias Gradient: tensor([-0.5731])
# Epoch 1, Weight Gradient: tensor([[-0.0487,  0.5990]]), Bias Gradient: tensor([-0.6000])
# Epoch 1, Weight Gradient: tensor([[-0.4350,  0.4969]]), Bias Gradient: tensor([-0.8000])
# Epoch 1, Weight Gradient: tensor([[-0.3865,  0.3355]]), Bias Gradient: tensor([-0.8401])
# Epoch 1, Weight Gradient: tensor([[0.1687, 0.6981]]), Bias Gradient: tensor([-0.6196])
# Epoch 1, Weight Gradient: tensor([[-0.3055,  0.1309]]), Bias Gradient: tensor([-0.6690])
# Epoch 1, Weight Gradient: tensor([[-0.8270,  0.4353]]), Bias Gradient: tensor([-0.7636])
# Epoch 1, Weight Gradient: tensor([[-0.0441,  0.1138]]), Bias Gradient: tensor([-0.5803])
# Epoch 1, Weight Gradient: tensor([[-0.3889,  0.4893]]), Bias Gradient: tensor([-0.8000])
# Epoch 1, Weight Gradient: tensor([[-0.0218,  0.1218]]), Bias Gradient: tensor([-0.5064])
# Epoch 1, Weight Gradient: tensor([[-0.3052,  1.0406]]), Bias Gradient: tensor([-0.7563])
# Epoch 1, Weight Gradient: tensor([[0.3085, 0.3582]]), Bias Gradient: tensor([-0.9893])
# Epoch 1, Weight Gradient: tensor([[0.4768, 0.4926]]), Bias Gradient: tensor([-0.6137])
# Epoch 1, Weight Gradient: tensor([[-0.7152, -0.1186]]), Bias Gradient: tensor([-0.6204])
# Epoch 1, Weight Gradient: tensor([[0.0763, 0.3557]]), Bias Gradient: tensor([-0.7529])
# Epoch 1, Weight Gradient: tensor([[-0.5187,  0.2339]]), Bias Gradient: tensor([-1.0000])
# Epoch 1, Weight Gradient: tensor([[-0.1601,  0.6853]]), Bias Gradient: tensor([-0.5656])
# Epoch 1, Weight Gradient: tensor([[-0.2407,  0.4012]]), Bias Gradient: tensor([-0.6579])
# Epoch 1, Weight Gradient: tensor([[-0.1099,  0.8192]]), Bias Gradient: tensor([-0.4964])
# Epoch 1, Weight Gradient: tensor([[-0.4463,  0.4920]]), Bias Gradient: tensor([-0.7585])
# Epoch 1, Weight Gradient: tensor([[-0.3091,  0.5008]]), Bias Gradient: tensor([-0.5518])
# Epoch 1, Weight Gradient: tensor([[0.3515, 0.7442]]), Bias Gradient: tensor([-0.2586])
# Epoch 1, Weight Gradient: tensor([[-0.0087,  0.2010]]), Bias Gradient: tensor([-0.6633])
# Epoch 1, Weight Gradient: tensor([[-0.4376,  0.2617]]), Bias Gradient: tensor([-0.6000])
# Epoch 1, Weight Gradient: tensor([[-0.1776,  0.4972]]), Bias Gradient: tensor([-0.9125])
# Epoch 1, Weight Gradient: tensor([[-0.5113,  0.1937]]), Bias Gradient: tensor([-0.3335])
# Epoch 1, Weight Gradient: tensor([[-0.0929,  0.6656]]), Bias Gradient: tensor([-0.9468])
# Epoch 1, Weight Gradient: tensor([[-0.1902,  0.3031]]), Bias Gradient: tensor([-0.8229])
# Epoch 1, Weight Gradient: tensor([[-0.1760,  0.5725]]), Bias Gradient: tensor([-0.5091])
# Epoch 1, Weight Gradient: tensor([[-0.1222,  0.4939]]), Bias Gradient: tensor([-0.1462])
# Epoch 1, Weight Gradient: tensor([[0.0347, 0.6657]]), Bias Gradient: tensor([-0.4702])
# Epoch 1, Weight Gradient: tensor([[0.0845, 0.4796]]), Bias Gradient: tensor([-0.8000])
# Epoch 1, Weight Gradient: tensor([[-0.3303,  0.4673]]), Bias Gradient: tensor([-1.0000])
# Epoch 1, Weight Gradient: tensor([[-0.3283,  0.3645]]), Bias Gradient: tensor([-0.5029])
# Epoch 1, Weight Gradient: tensor([[-0.1980,  0.2663]]), Bias Gradient: tensor([-0.8000])
# Epoch 1, Weight Gradient: tensor([[-0.3062,  0.7530]]), Bias Gradient: tensor([-0.5878])
# epoch 1, loss 2.213929
# Epoch 2, Weight Gradient: tensor([[0.0657, 1.1038]]), Bias Gradient: tensor([-0.5854])
# Epoch 2, Weight Gradient: tensor([[-0.6153,  0.1702]]), Bias Gradient: tensor([-0.9528])
# Epoch 2, Weight Gradient: tensor([[-0.5797,  0.2068]]), Bias Gradient: tensor([-0.7068])
# Epoch 2, Weight Gradient: tensor([[-0.0388,  0.4491]]), Bias Gradient: tensor([-0.6452])
# Epoch 2, Weight Gradient: tensor([[-0.0942,  0.1586]]), Bias Gradient: tensor([-0.6262])
# Epoch 2, Weight Gradient: tensor([[-0.5896,  0.3110]]), Bias Gradient: tensor([-0.2270])
# Epoch 2, Weight Gradient: tensor([[-0.0157,  0.3957]]), Bias Gradient: tensor([-1.0000])
# Epoch 2, Weight Gradient: tensor([[-0.1591,  0.5776]]), Bias Gradient: tensor([-0.7540])
# Epoch 2, Weight Gradient: tensor([[-0.6701,  0.4579]]), Bias Gradient: tensor([-0.4000])
# Epoch 2, Weight Gradient: tensor([[-0.6579,  0.9157]]), Bias Gradient: tensor([-0.0117])
# Epoch 2, Weight Gradient: tensor([[-0.2343,  0.6263]]), Bias Gradient: tensor([-0.1125])
# Epoch 2, Weight Gradient: tensor([[0.0128, 0.1965]]), Bias Gradient: tensor([-0.6933])
# Epoch 2, Weight Gradient: tensor([[0.0315, 0.2895]]), Bias Gradient: tensor([-0.5623])
# Epoch 2, Weight Gradient: tensor([[-0.3287, -0.2680]]), Bias Gradient: tensor([-0.9303])
# Epoch 2, Weight Gradient: tensor([[0.0569, 0.6846]]), Bias Gradient: tensor([-0.5505])
# Epoch 2, Weight Gradient: tensor([[-0.5343,  0.1414]]), Bias Gradient: tensor([-0.5614])
# Epoch 2, Weight Gradient: tensor([[0.0238, 0.6387]]), Bias Gradient: tensor([-0.2594])
# Epoch 2, Weight Gradient: tensor([[-0.0128,  0.3989]]), Bias Gradient: tensor([-0.5680])
# Epoch 2, Weight Gradient: tensor([[-0.6349,  0.5202]]), Bias Gradient: tensor([-0.3610])
# Epoch 2, Weight Gradient: tensor([[-0.3909,  0.5447]]), Bias Gradient: tensor([-0.7339])
# Epoch 2, Weight Gradient: tensor([[-0.4722,  0.5595]]), Bias Gradient: tensor([-0.4851])
# Epoch 2, Weight Gradient: tensor([[-0.2614,  0.0821]]), Bias Gradient: tensor([-0.9138])
# Epoch 2, Weight Gradient: tensor([[-0.3838,  0.5457]]), Bias Gradient: tensor([-0.3603])
# Epoch 2, Weight Gradient: tensor([[-0.6260,  0.1980]]), Bias Gradient: tensor([-0.7216])
# Epoch 2, Weight Gradient: tensor([[0.1632, 0.4008]]), Bias Gradient: tensor([-0.8096])
# Epoch 2, Weight Gradient: tensor([[-0.3706,  0.9098]]), Bias Gradient: tensor([-0.3356])
# Epoch 2, Weight Gradient: tensor([[-0.1685,  0.4606]]), Bias Gradient: tensor([-0.4831])
# Epoch 2, Weight Gradient: tensor([[0.1328, 0.5581]]), Bias Gradient: tensor([-0.4498])
# Epoch 2, Weight Gradient: tensor([[-0.2496, -0.1028]]), Bias Gradient: tensor([-0.6436])
# Epoch 2, Weight Gradient: tensor([[-0.7830,  0.1269]]), Bias Gradient: tensor([-0.7571])
# Epoch 2, Weight Gradient: tensor([[-0.5613,  0.5275]]), Bias Gradient: tensor([-0.8000])
# Epoch 2, Weight Gradient: tensor([[-0.5716,  0.5257]]), Bias Gradient: tensor([-0.3251])
# Epoch 2, Weight Gradient: tensor([[-0.0798,  0.6206]]), Bias Gradient: tensor([-0.7174])
# Epoch 2, Weight Gradient: tensor([[-0.4203,  0.1038]]), Bias Gradient: tensor([-0.4437])
# Epoch 2, Weight Gradient: tensor([[-0.0061,  0.5876]]), Bias Gradient: tensor([-0.7061])
# Epoch 2, Weight Gradient: tensor([[-0.7489,  0.5357]]), Bias Gradient: tensor([-0.8367])
# Epoch 2, Weight Gradient: tensor([[-0.7762,  0.4029]]), Bias Gradient: tensor([-0.4466])
# Epoch 2, Weight Gradient: tensor([[0.1988, 0.4635]]), Bias Gradient: tensor([-0.6647])
# Epoch 2, Weight Gradient: tensor([[-0.2916,  0.4080]]), Bias Gradient: tensor([-0.3698])
# Epoch 2, Weight Gradient: tensor([[-0.5999,  0.3431]]), Bias Gradient: tensor([-0.5084])
# Epoch 2, Weight Gradient: tensor([[-0.8017,  0.1688]]), Bias Gradient: tensor([-0.2848])
# Epoch 2, Weight Gradient: tensor([[0.0513, 0.4395]]), Bias Gradient: tensor([-0.2573])
# Epoch 2, Weight Gradient: tensor([[-0.0944,  0.5910]]), Bias Gradient: tensor([-0.7486])
# Epoch 2, Weight Gradient: tensor([[-0.5357,  0.4920]]), Bias Gradient: tensor([-0.5368])
# Epoch 2, Weight Gradient: tensor([[-0.2703,  0.7437]]), Bias Gradient: tensor([-0.4967])
# Epoch 2, Weight Gradient: tensor([[-0.6600,  0.2487]]), Bias Gradient: tensor([-0.7120])
# Epoch 2, Weight Gradient: tensor([[-0.1937,  0.6410]]), Bias Gradient: tensor([-0.2679])
# Epoch 2, Weight Gradient: tensor([[-0.4441,  0.8347]]), Bias Gradient: tensor([-0.5310])
# Epoch 2, Weight Gradient: tensor([[-0.3786,  0.2895]]), Bias Gradient: tensor([-0.8425])
# Epoch 2, Weight Gradient: tensor([[0.0078, 0.4789]]), Bias Gradient: tensor([-0.7364])
# Epoch 2, Weight Gradient: tensor([[-0.6995,  0.1291]]), Bias Gradient: tensor([-0.6617])
# Epoch 2, Weight Gradient: tensor([[-0.4284,  0.7306]]), Bias Gradient: tensor([-0.6452])
# Epoch 2, Weight Gradient: tensor([[-0.1136,  0.4038]]), Bias Gradient: tensor([-0.4804])
# Epoch 2, Weight Gradient: tensor([[-0.2288,  0.3055]]), Bias Gradient: tensor([-0.4899])
# Epoch 2, Weight Gradient: tensor([[0.1142, 0.2184]]), Bias Gradient: tensor([-0.7220])
# Epoch 2, Weight Gradient: tensor([[-0.4446,  0.4945]]), Bias Gradient: tensor([-0.3735])
# Epoch 2, Weight Gradient: tensor([[-0.3332,  0.4082]]), Bias Gradient: tensor([-0.6986])
# Epoch 2, Weight Gradient: tensor([[-0.3177,  0.2363]]), Bias Gradient: tensor([-0.4077])
# Epoch 2, Weight Gradient: tensor([[-0.3553,  0.3808]]), Bias Gradient: tensor([-0.7368])
# Epoch 2, Weight Gradient: tensor([[-0.3326,  0.5669]]), Bias Gradient: tensor([-0.5123])
# Epoch 2, Weight Gradient: tensor([[0.0802, 0.4968]]), Bias Gradient: tensor([-0.5473])
# Epoch 2, Weight Gradient: tensor([[-0.2164,  0.5205]]), Bias Gradient: tensor([-0.0840])
# Epoch 2, Weight Gradient: tensor([[0.1732, 0.6138]]), Bias Gradient: tensor([-0.6955])
# Epoch 2, Weight Gradient: tensor([[-0.0009,  0.4100]]), Bias Gradient: tensor([-0.4336])
# Epoch 2, Weight Gradient: tensor([[-0.2500,  0.5782]]), Bias Gradient: tensor([-0.5621])
# Epoch 2, Weight Gradient: tensor([[-0.3295,  0.4491]]), Bias Gradient: tensor([-0.3622])
# Epoch 2, Weight Gradient: tensor([[-0.0187,  0.6917]]), Bias Gradient: tensor([-0.1138])
# Epoch 2, Weight Gradient: tensor([[-0.2380,  1.1858]]), Bias Gradient: tensor([-0.6473])
# Epoch 2, Weight Gradient: tensor([[-0.2345,  0.3105]]), Bias Gradient: tensor([-0.5488])
# Epoch 2, Weight Gradient: tensor([[-0.3647,  0.4598]]), Bias Gradient: tensor([-0.3127])
# Epoch 2, Weight Gradient: tensor([[0.2167, 0.7310]]), Bias Gradient: tensor([-0.4901])
# Epoch 2, Weight Gradient: tensor([[-0.3360,  1.1156]]), Bias Gradient: tensor([-0.5506])
# Epoch 2, Weight Gradient: tensor([[-0.7790,  0.4963]]), Bias Gradient: tensor([-0.4170])
# Epoch 2, Weight Gradient: tensor([[-0.2790,  0.6899]]), Bias Gradient: tensor([-0.4485])
# Epoch 2, Weight Gradient: tensor([[-0.3436,  0.2108]]), Bias Gradient: tensor([-0.5881])
# Epoch 2, Weight Gradient: tensor([[-0.0932,  0.1688]]), Bias Gradient: tensor([-0.6205])
# Epoch 2, Weight Gradient: tensor([[-0.3873,  0.3429]]), Bias Gradient: tensor([-0.6403])
# Epoch 2, Weight Gradient: tensor([[-0.3658,  0.4829]]), Bias Gradient: tensor([-0.6216])
# Epoch 2, Weight Gradient: tensor([[-0.3901,  0.2494]]), Bias Gradient: tensor([-0.5739])
# Epoch 2, Weight Gradient: tensor([[-0.0512,  0.8359]]), Bias Gradient: tensor([-0.2344])
# Epoch 2, Weight Gradient: tensor([[-0.1771,  0.8941]]), Bias Gradient: tensor([-0.4311])
# Epoch 2, Weight Gradient: tensor([[0.0102, 0.4372]]), Bias Gradient: tensor([-0.4437])
# Epoch 2, Weight Gradient: tensor([[-0.3143,  0.9626]]), Bias Gradient: tensor([-0.2760])
# Epoch 2, Weight Gradient: tensor([[-0.1731,  0.5629]]), Bias Gradient: tensor([-0.4152])
# Epoch 2, Weight Gradient: tensor([[0.1638, 0.3749]]), Bias Gradient: tensor([-0.7929])
# Epoch 2, Weight Gradient: tensor([[-0.4021,  0.5615]]), Bias Gradient: tensor([-0.8001])
# Epoch 2, Weight Gradient: tensor([[0.2361, 0.3381]]), Bias Gradient: tensor([-0.4180])
# Epoch 2, Weight Gradient: tensor([[-0.3362,  0.3818]]), Bias Gradient: tensor([-0.4084])
# Epoch 2, Weight Gradient: tensor([[-0.8006,  0.8481]]), Bias Gradient: tensor([-0.3005])
# Epoch 2, Weight Gradient: tensor([[-0.3312,  0.6396]]), Bias Gradient: tensor([-0.4912])
# Epoch 2, Weight Gradient: tensor([[-0.2867,  0.2202]]), Bias Gradient: tensor([-0.4526])
# Epoch 2, Weight Gradient: tensor([[-0.5911,  0.4369]]), Bias Gradient: tensor([-0.4376])
# Epoch 2, Weight Gradient: tensor([[-0.1630,  1.0290]]), Bias Gradient: tensor([-0.7296])
# Epoch 2, Weight Gradient: tensor([[-0.1619,  0.5854]]), Bias Gradient: tensor([-0.4183])
# Epoch 2, Weight Gradient: tensor([[-0.6442,  0.4449]]), Bias Gradient: tensor([-0.7892])
# Epoch 2, Weight Gradient: tensor([[-0.2063,  0.2236]]), Bias Gradient: tensor([-0.5911])
# Epoch 2, Weight Gradient: tensor([[-0.2178,  0.3926]]), Bias Gradient: tensor([-0.0300])
# Epoch 2, Weight Gradient: tensor([[0.1371, 0.3624]]), Bias Gradient: tensor([-0.4916])
# Epoch 2, Weight Gradient: tensor([[-0.1231,  0.2317]]), Bias Gradient: tensor([-0.4658])
# Epoch 2, Weight Gradient: tensor([[-0.5657,  0.7562]]), Bias Gradient: tensor([-0.2979])
# epoch 2, loss 0.451169
# Epoch 3, Weight Gradient: tensor([[-0.1925,  0.5662]]), Bias Gradient: tensor([-0.1823])
# Epoch 3, Weight Gradient: tensor([[-0.6421,  0.6508]]), Bias Gradient: tensor([-0.5630])
# Epoch 3, Weight Gradient: tensor([[-0.4245,  0.3782]]), Bias Gradient: tensor([-0.1587])
# Epoch 3, Weight Gradient: tensor([[-0.0712,  0.3448]]), Bias Gradient: tensor([-0.7516])
# Epoch 3, Weight Gradient: tensor([[-0.1837,  0.2784]]), Bias Gradient: tensor([-0.3236])
# Epoch 3, Weight Gradient: tensor([[-0.6603,  0.4430]]), Bias Gradient: tensor([-0.5750])
# Epoch 3, Weight Gradient: tensor([[-0.3616,  0.5082]]), Bias Gradient: tensor([-0.3812])
# Epoch 3, Weight Gradient: tensor([[-0.2917,  0.2112]]), Bias Gradient: tensor([-0.2942])
# Epoch 3, Weight Gradient: tensor([[-0.0870,  0.5832]]), Bias Gradient: tensor([-0.3458])
# Epoch 3, Weight Gradient: tensor([[0.1143, 0.4540]]), Bias Gradient: tensor([-0.6068])
# Epoch 3, Weight Gradient: tensor([[0.1719, 0.2993]]), Bias Gradient: tensor([-0.3044])
# Epoch 3, Weight Gradient: tensor([[-0.7756,  0.4621]]), Bias Gradient: tensor([-0.6076])
# Epoch 3, Weight Gradient: tensor([[0.1940, 0.7619]]), Bias Gradient: tensor([-0.3886])
# Epoch 3, Weight Gradient: tensor([[-0.3536,  0.1997]]), Bias Gradient: tensor([-0.4940])
# Epoch 3, Weight Gradient: tensor([[-0.2011,  0.2308]]), Bias Gradient: tensor([-0.4375])
# Epoch 3, Weight Gradient: tensor([[-0.2859,  0.6715]]), Bias Gradient: tensor([-0.2899])
# Epoch 3, Weight Gradient: tensor([[0.0137, 0.6244]]), Bias Gradient: tensor([-0.1172])
# Epoch 3, Weight Gradient: tensor([[-0.2383,  0.2366]]), Bias Gradient: tensor([-0.4002])
# Epoch 3, Weight Gradient: tensor([[-0.2346,  0.5142]]), Bias Gradient: tensor([-0.4645])
# Epoch 3, Weight Gradient: tensor([[-0.1034,  0.6004]]), Bias Gradient: tensor([-0.5664])
# Epoch 3, Weight Gradient: tensor([[-0.1583,  0.5329]]), Bias Gradient: tensor([-0.4711])
# Epoch 3, Weight Gradient: tensor([[-0.3002,  0.4025]]), Bias Gradient: tensor([-0.5013])
# Epoch 3, Weight Gradient: tensor([[-0.0100,  0.2696]]), Bias Gradient: tensor([-0.4423])
# Epoch 3, Weight Gradient: tensor([[-0.3414,  0.6746]]), Bias Gradient: tensor([-0.0173])
# Epoch 3, Weight Gradient: tensor([[-0.2769,  0.4338]]), Bias Gradient: tensor([-0.1525])
# Epoch 3, Weight Gradient: tensor([[-0.3947,  0.2967]]), Bias Gradient: tensor([-0.2060])
# Epoch 3, Weight Gradient: tensor([[-0.1162,  0.3125]]), Bias Gradient: tensor([-0.0489])
# Epoch 3, Weight Gradient: tensor([[-0.2068,  0.4924]]), Bias Gradient: tensor([-0.1947])
# Epoch 3, Weight Gradient: tensor([[-0.0230,  0.4100]]), Bias Gradient: tensor([-0.2850])
# Epoch 3, Weight Gradient: tensor([[-0.0095,  0.7488]]), Bias Gradient: tensor([-0.2854])
# Epoch 3, Weight Gradient: tensor([[-0.4285,  0.3074]]), Bias Gradient: tensor([-0.2987])
# Epoch 3, Weight Gradient: tensor([[0.1441, 0.4127]]), Bias Gradient: tensor([-0.3048])
# Epoch 3, Weight Gradient: tensor([[-0.3036,  0.3888]]), Bias Gradient: tensor([-0.1705])
# Epoch 3, Weight Gradient: tensor([[0.0331, 0.2527]]), Bias Gradient: tensor([-0.3172])
# Epoch 3, Weight Gradient: tensor([[-0.2099,  0.3094]]), Bias Gradient: tensor([-0.2706])
# Epoch 3, Weight Gradient: tensor([[0.0173, 0.0729]]), Bias Gradient: tensor([-0.0444])
# Epoch 3, Weight Gradient: tensor([[-0.1642,  0.4929]]), Bias Gradient: tensor([-0.3036])
# Epoch 3, Weight Gradient: tensor([[-0.0926,  0.6272]]), Bias Gradient: tensor([-0.4090])
# Epoch 3, Weight Gradient: tensor([[-0.1900,  0.1865]]), Bias Gradient: tensor([-0.1798])
# Epoch 3, Weight Gradient: tensor([[-0.1341,  0.0974]]), Bias Gradient: tensor([-0.1352])
# Epoch 3, Weight Gradient: tensor([[-0.2041,  0.4560]]), Bias Gradient: tensor([-0.0401])
# Epoch 3, Weight Gradient: tensor([[-0.1370,  0.4586]]), Bias Gradient: tensor([-0.0750])
# Epoch 3, Weight Gradient: tensor([[-0.2889,  0.1429]]), Bias Gradient: tensor([-0.2447])
# Epoch 3, Weight Gradient: tensor([[-0.1903,  0.3266]]), Bias Gradient: tensor([-0.2335])
# Epoch 3, Weight Gradient: tensor([[-0.0362,  0.1709]]), Bias Gradient: tensor([0.0116])
# Epoch 3, Weight Gradient: tensor([[0.0419, 0.3514]]), Bias Gradient: tensor([-0.2417])
# Epoch 3, Weight Gradient: tensor([[-0.1878,  0.0917]]), Bias Gradient: tensor([-0.1011])
# Epoch 3, Weight Gradient: tensor([[0.0669, 0.2712]]), Bias Gradient: tensor([-0.1952])
# Epoch 3, Weight Gradient: tensor([[-0.1502,  0.1358]]), Bias Gradient: tensor([-0.1606])
# Epoch 3, Weight Gradient: tensor([[-0.0074,  0.2129]]), Bias Gradient: tensor([-0.1727])
# Epoch 3, Weight Gradient: tensor([[-0.0413,  0.1683]]), Bias Gradient: tensor([-0.1068])
# Epoch 3, Weight Gradient: tensor([[-0.1811,  0.0682]]), Bias Gradient: tensor([-0.1978])
# Epoch 3, Weight Gradient: tensor([[-0.1916,  0.1039]]), Bias Gradient: tensor([-0.1882])
# Epoch 3, Weight Gradient: tensor([[-0.0543,  0.0927]]), Bias Gradient: tensor([-0.0814])
# Epoch 3, Weight Gradient: tensor([[-0.1313,  0.1270]]), Bias Gradient: tensor([-0.0503])
# Epoch 3, Weight Gradient: tensor([[-0.2535,  0.3179]]), Bias Gradient: tensor([-0.1776])
# Epoch 3, Weight Gradient: tensor([[-0.0672,  0.1101]]), Bias Gradient: tensor([0.0430])
# Epoch 3, Weight Gradient: tensor([[0.0228, 0.0760]]), Bias Gradient: tensor([-0.1420])
# Epoch 3, Weight Gradient: tensor([[-0.0695,  0.0883]]), Bias Gradient: tensor([-0.1948])
# Epoch 3, Weight Gradient: tensor([[0.0277, 0.1628]]), Bias Gradient: tensor([-0.0720])
# Epoch 3, Weight Gradient: tensor([[-0.1324,  0.1211]]), Bias Gradient: tensor([0.0610])
# Epoch 3, Weight Gradient: tensor([[-0.1008,  0.2643]]), Bias Gradient: tensor([-0.1174])
# Epoch 3, Weight Gradient: tensor([[-0.1186,  0.1892]]), Bias Gradient: tensor([0.0195])
# Epoch 3, Weight Gradient: tensor([[-0.0566,  0.1440]]), Bias Gradient: tensor([-0.1606])
# Epoch 3, Weight Gradient: tensor([[-0.0281,  0.1170]]), Bias Gradient: tensor([-0.1184])
# Epoch 3, Weight Gradient: tensor([[-0.1836,  0.2031]]), Bias Gradient: tensor([-0.0978])
# Epoch 3, Weight Gradient: tensor([[-0.0119,  0.0385]]), Bias Gradient: tensor([-0.0658])
# Epoch 3, Weight Gradient: tensor([[-0.0269,  0.1506]]), Bias Gradient: tensor([-0.1139])
# Epoch 3, Weight Gradient: tensor([[0.0136, 0.1540]]), Bias Gradient: tensor([-0.1291])
# Epoch 3, Weight Gradient: tensor([[-0.1580,  0.1232]]), Bias Gradient: tensor([-0.0365])
# Epoch 3, Weight Gradient: tensor([[-0.0450,  0.1652]]), Bias Gradient: tensor([-0.1327])
# Epoch 3, Weight Gradient: tensor([[-0.1240,  0.0758]]), Bias Gradient: tensor([-0.1031])
# Epoch 3, Weight Gradient: tensor([[-0.0093,  0.1476]]), Bias Gradient: tensor([-0.0727])
# Epoch 3, Weight Gradient: tensor([[-0.1301,  0.0696]]), Bias Gradient: tensor([-0.1030])
# Epoch 3, Weight Gradient: tensor([[-0.0367,  0.0450]]), Bias Gradient: tensor([-0.0687])
# Epoch 3, Weight Gradient: tensor([[-0.0761,  0.1473]]), Bias Gradient: tensor([-0.0716])
# Epoch 3, Weight Gradient: tensor([[-0.0922,  0.1430]]), Bias Gradient: tensor([-0.0243])
# Epoch 3, Weight Gradient: tensor([[0.0091, 0.1149]]), Bias Gradient: tensor([-0.0760])
# Epoch 3, Weight Gradient: tensor([[-0.0710,  0.1191]]), Bias Gradient: tensor([-0.0339])
# Epoch 3, Weight Gradient: tensor([[-0.0560,  0.1597]]), Bias Gradient: tensor([-0.0648])
# Epoch 3, Weight Gradient: tensor([[-0.0880,  0.1437]]), Bias Gradient: tensor([-0.0947])
# Epoch 3, Weight Gradient: tensor([[-0.0575,  0.0692]]), Bias Gradient: tensor([-0.1101])
# Epoch 3, Weight Gradient: tensor([[-0.0531,  0.0372]]), Bias Gradient: tensor([-0.0765])
# Epoch 3, Weight Gradient: tensor([[-0.0965,  0.1170]]), Bias Gradient: tensor([-0.0368])
# Epoch 3, Weight Gradient: tensor([[0.0066, 0.2176]]), Bias Gradient: tensor([0.0216])
# Epoch 3, Weight Gradient: tensor([[-0.0217,  0.0321]]), Bias Gradient: tensor([-0.0527])
# Epoch 3, Weight Gradient: tensor([[-0.0245,  0.0257]]), Bias Gradient: tensor([-0.0329])
# Epoch 3, Weight Gradient: tensor([[-0.0776,  0.0617]]), Bias Gradient: tensor([-0.0467])
# Epoch 3, Weight Gradient: tensor([[-0.0269,  0.0945]]), Bias Gradient: tensor([-0.0692])
# Epoch 3, Weight Gradient: tensor([[-0.0213,  0.0833]]), Bias Gradient: tensor([-0.0441])
# Epoch 3, Weight Gradient: tensor([[-0.0274,  0.0587]]), Bias Gradient: tensor([-0.0526])
# Epoch 3, Weight Gradient: tensor([[-0.0446,  0.0238]]), Bias Gradient: tensor([-0.0332])
# Epoch 3, Weight Gradient: tensor([[-0.0174,  0.0412]]), Bias Gradient: tensor([-0.0578])
# Epoch 3, Weight Gradient: tensor([[-0.0594,  0.0460]]), Bias Gradient: tensor([-0.0543])
# Epoch 3, Weight Gradient: tensor([[-0.0313,  0.0048]]), Bias Gradient: tensor([-0.0382])
# Epoch 3, Weight Gradient: tensor([[-0.0642,  0.0267]]), Bias Gradient: tensor([-0.0419])
# Epoch 3, Weight Gradient: tensor([[-0.0349,  0.1156]]), Bias Gradient: tensor([-0.0238])
# Epoch 3, Weight Gradient: tensor([[-0.0042,  0.0473]]), Bias Gradient: tensor([-0.0147])
# Epoch 3, Weight Gradient: tensor([[0.0012, 0.0267]]), Bias Gradient: tensor([-0.0158])
# Epoch 3, Weight Gradient: tensor([[-0.0070,  0.0363]]), Bias Gradient: tensor([-0.0248])
# epoch 3, loss 0.002219
# w的估计误差： tensor([ 0.0224, -0.0540])
# b的估计误差： tensor([0.0340])
